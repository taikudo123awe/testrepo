# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.read_csv('dulieuxettuyendaihoc.csv',header = 0, delimiter=',', encoding='UTF-8')
df
# Out:
#        MSSV GT  DT   KV    M1    M2    M3  KT    NGAYTHI DINHHUONGNGHENGHIEP
# 0     SV001  F NaN  2NT  3.25  3.25  4.50  A1  12/7/2018                  No
# 1     SV002  M NaN    1  6.00  4.00  3.50   C  12/7/2018                 Yes
# 2     SV003  M NaN    1  5.00  6.75  4.00   C  12/7/2018                  No
# 3     SV004  M NaN    1  4.25  4.25  5.25  D1  12/7/2018                  No
# 4     SV005  M NaN  2NT  4.25  4.50  5.00   A  12/7/2018                  No
# ..      ... ..  ..  ...   ...   ...   ...  ..        ...                 ...
# 95   SV0096  F NaN    1  5.25  1.50  6.25   C  7/20/2022                 Yes
# 96   SV0097  F NaN    1  5.25  3.75  4.75   C  7/20/2022                  No
# 97   SV0098  M NaN  2NT  7.00  8.00  4.00   C  7/20/2022                 Yes
# 98   SV0099  M NaN    1  5.00  3.50  5.50   C  7/20/2022                  No
# 99  SV00100  M NaN  2NT  5.25  2.50  4.25   C  7/20/2022                 Yes
#
# [100 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MSSV                 100 non-null    object
#  1   GT                   100 non-null    object
#  2   DT                   3 non-null      float64
#  3   KV                   100 non-null    object
#  4   M1                   100 non-null    float64
#  5   M2                   100 non-null    float64
#  6   M3                   100 non-null    float64
#  7   KT                   100 non-null    object
#  8   NGAYTHI              100 non-null    object
#  9   DINHHUONGNGHENGHIEP  100 non-null    object
# dtypes: float64(4), object(6)
# memory usage: 7.9+ KB

# %%
#đo lường mức độ taapjj trung
print(f'{df["M1"].min()}\n{df["M1"].max()}\n')
print(f'{df["M1"].mean()}\n{df["M1"].median()}\n')
print(f'{df["KT"].mode()}\n')
print(f'{df["M1"].quantile(0.25)}\n') #phân vị Q1
# Out:
# 1.0
# 7.0
#
# 3.74
# 3.625
#
# 0    A
# Name: KT, dtype: object
#
# 2.5

# %%
# các đại lượng đo lượng biến động
#range 
range =  df['M1'].max() - df['M1'].min()
print(range)
# Out:
# 6.0

# %%
#IQR
IQR =  df['M1'].quantile(0.75) - df['M1'].quantile(0.25)
print(IQR)
# Out:
# 2.25

# %%
#độ lệch trung bình 
deltaD = np.mean(np.abs(df['M1'] - np.mean(df['M1'])))
print(deltaD)
# Out:
# 1.1600000000000001

# %%
#Tính phân vị thứ 9 trong thập phân vị cho M1 và M2
print(df['M1'].quantile(0.9))
print(df['M2'].quantile(0.9))
# Out:
# 5.300000000000004
# 5.5

# %%
#tính khoảng range cho M1 và M2
df[['M1','M2']].max() - df[['M1','M2']].min()
# Out:
# M1    6.0
# M2    6.5
# dtype: float64

# %%
#tính khoảng IQR cho M1 và M2
df[['M1','M2']].quantile(0.75) - df[['M1','M2']].quantile(0.25)
# Out:
# M1    2.25
# M2    1.25
# dtype: float64

# %%
# tính độ lệch trung bình Cho M1 vầ M2

a = np.mean(np.abs(df[['M1', 'M2']] - np.mean(df[['M1', 'M2']])))
a
# Out:
# np.float64(0.9977000000000001)

# %%
#Phương sai đo lường độ biến động
df['M1'].var()
# Out:
# np.float64(2.0289393939393943)

# %%
#độ lệch chuẩn m1
df['M1'].std()
# Out:
# np.float64(1.424408436488423)

# %%
#phương pháp dùng std để so sánh mức độ biến động của 2 hay nhiều biến số 

print(df[['M1','M2']].mean())
print(df[['M1','M2']].std())
# Out:
# M1    3.740
# M2    4.255
# dtype: float64
# M1    1.424408
# M2    1.060053
# dtype: float64

# %%
df[['M1','M2']].std()/df[['M1','M2']].mean()
# Out:
# M1    0.380858
# M2    0.249131
# dtype: float64

# %%
# mô tả biến định lượng
df['M1'].describe()
# Out:
# count    100.000000
# mean       3.740000
# std        1.424408
# min        1.000000
# 25%        2.500000
# 50%        3.625000
# 75%        4.750000
# max        7.000000
# Name: M1, dtype: float64

# %%
df[['M1','M2','M3']].describe()
# Out:
#                M1          M2          M3
# count  100.000000  100.000000  100.000000
# mean     3.740000    4.255000    4.875000
# std      1.424408    1.060053    1.041136
# min      1.000000    1.500000    2.750000
# 25%      2.500000    3.500000    4.250000
# 50%      3.625000    4.125000    4.750000
# 75%      4.750000    4.750000    5.500000
# max      7.000000    8.000000    8.000000

# %%
# So sánh mức độ ổn định của điểm số

#trong kì thi đánh giá năng lực

# Hãy sắp xếp tăng dần mức độ ổn định trong 3 cột điểm

# Gợi ý: hướng dẫn giá trị CV (cofficient of variant)
# Bài tập: Sinh viên viết code để tìm ra những

# môn nào có độ ổn định nhất

# và độ biến động cao nhất

# %%
cv = df[['M1','M2','M3']].std() / df[['M1','M2','M3']].mean()
list(cv)
# Out:
# [0.3808578707188297, 0.2491311130540305, 0.2135664058628459]

# %%
df.groupby('GT')['M1'].describe()
# Out:
#     count      mean       std   min     25%   50%  75%  max
# GT
# F    48.0  3.854167  1.348594  1.25  3.1875  3.75  5.0  7.0
# M    52.0  3.634615  1.496288  1.00  2.4375  3.50  4.5  7.0

# %%
df.groupby('GT')['M2'].std()/df.groupby('GT')['M2'].mean()
# Out:
# GT
# F    0.252518
# M    0.240146
# Name: M2, dtype: float64

# %%
#sinh viên có giới tính nam học môn nào tốt hơn so với nữ
df.groupby('GT')[['M1','M2','M3']].describe()
df.groupby('GT')[['M1','M2','M3']].std()/df.groupby('GT')[['M1','M2','M3']].mean()
# Out:
#           M1        M2        M3
# GT
# F   0.349905  0.252518  0.192854
# M   0.411677  0.240146  0.233215

# %%
#cho biết khoảng điểm M1 của sinh viên cao nhất trong khoảng bao nhiêu và thấp nhất trong khoảng bao nhiêu


df['M1'].hist()
plt.show()

# %%
#khi số lượng bin khác nhau thì khoảng phân bổ càng rõ ràng

df['M1'].hist(bins=14)
plt.show()

# %%
#nâng cao hơn 
sns.displot(df, x='M1', kind='kde')
plt.show()

# %%
#cho biết biến số nào gần với pp chuẩn nhấtt
sns.displot(data = df[['M1','M2','M3']], kind='kde')
plt.show()

# %%
#cho biết biến số nào gần với pp chuẩn nhấtt
sns.displot(df, x='M1', hue='GT', kind='kde')
plt.show()

# %%
df['M1'].skew()
# Out:
# np.float64(0.33322084231625376)

# %%
df[['M1','M2','M3']].skew()
# Out:
# M1    0.333221
# M2    0.472551
# M3    0.607063
# dtype: float64

# %%
df[['M1']].kurtosis()
# Out:
# M1   -0.517004
# dtype: float64

# %%
df[['M1','M2','M3']].kurtosis()
#M3 gần phân phối chuẩn nhất vì nó tiệm cận số 0
# Out:
# M1   -0.517004
# M2    1.372439
# M3    0.442173
# dtype: float64

# %%
sns.displot(data = df[['M1','M2']], kind='kde')
plt.show()

# %%
sns.boxplot(data=df['M1'], orient="h")
plt.show()

# %%
#có dấu chấm là giấ trị bất thường
sns.boxplot(data=df[['M1','M2','M3']], orient='h')
plt.show()

# %%
sns.boxplot(x='M1', y='KT',data=df, orient='h')
plt.show()

# %%
sns.boxplot(x='M1', y='GT',data=df, orient='h')
plt.show()
#yếu tố giới tính đóng vai  trò dự báo điểm cho môn học M1

# %%
sns.boxplot(x='KT', y='M1',hue='GT',data=df)
plt.show()

# %%
from scipy import stats

#Biểu đồ kiểm định phân phối chuẩn
stats.probplot(df['M1'],plot=sns.mpl.pyplot)
plt.show()
#--> M1 không theo phân phối chuẩn

# %%
df[['M1','M2']].cov()
# Out:
#           M1        M2
# M1  2.028939  0.053081
# M2  0.053081  1.123712

# %%
#tính tương quang liên hệ giữa M1 với M3, M2 với M3
df[['M1','M2','M3']].cov()
# Out:
#           M1        M2        M3
# M1  2.028939  0.053081  0.027778
# M2  0.053081  1.123712 -0.101010
# M3  0.027778 -0.101010  1.083965

# %%
df[['M1','M2']].corr()
# Out:
#           M1        M2
# M1  1.000000  0.035154
# M2  0.035154  1.000000

# %%
sns.lmplot(data=df, x='M1', y='M2', fit_reg=True)
plt.show()

# %%
sns.lmplot(data=df, x='M2', y='M3', fit_reg=True)
plt.show()

# %%
#sắp xếp mức độ tác động của M1 với M2 và M3
df[['M1','M2','M3']].corr()
# Out:
#           M1        M2        M3
# M1  1.000000  0.035154  0.018731
# M2  0.035154  1.000000 -0.091523
# M3  0.018731 -0.091523  1.000000

# %%
sns.heatmap(df[['M1','M2','M3']].corr(), vmax=1.0, square=False).xaxis.tick_top()

# %%
sns.lmplot(data=df, x='M1', y='M2',hue='GT', fit_reg=True)
plt.show()

# %%
sns.pairplot(df[['M1','M2','M3']],diag_kind='kde', kind='reg')
plt.show()
